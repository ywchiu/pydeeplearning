# %% [markdown]
# ## 引用相关套件

# %%
import argparse
import skimage as skimage
from skimage import transform, color, exposure
from skimage.transform import rotate
from skimage.viewer import ImageViewer
import sys

sys.path.append("game/")
import wrapped_flappy_bird as game
import random
import numpy as np
from collections import deque

import json
from keras.initializers import normal, identity
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD , Adam
import tensorflow as tf

# %% [markdown]
# ## 设定训练相关参数

# %%
GAME    = 'bird'             # 游戏Log名称
ACTIONS = 2                  # 动作种类 (0: Not Flap, 1: Flap)
GAMMA   = 0.99               # 动作衰退 decay
OBSERVATION       = 3200.    # 训练前观察的步骤
EXPLORE          = 3000000.  # 逐渐降低episilon的总步数
FINAL_EPSILON    = 0.0001    # epsilon最后的值
INITIAL_EPSILON  = 0.1       # epsilon的初始值
REPLAY_MEMORY    = 50000     # Replay 记忆最大长度
BATCH            = 32        # mini-batch的大小
FRAME_PER_ACTION = 1         # 每个动作对应到的帧 (Frame)
LEARNING_RATE    = 1e-4      # 学习率

img_rows , img_cols = 80, 80 # 输入图片大小

img_channels = 4             # 帧数量

# %% [markdown]
# ## 训练网路

# %%
def trainNetwork(model,args):
    # 起始游戏
    game_state = game.GameState()

    # 将过去的观察记忆在经验回放纪录（Experience Replay）D中
    D = deque()

    #  什么都不做取得第一个状态并开始预处理80X80X4大小的图
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal = game_state.frame_step(do_nothing)

    """
    r_0 代表 reward
    r_0 分为三种：
    0.1 : 代表bird活着
    +1  : 代表bird通过了水管
    -1  : 代表bird死亡
    
    terminal是个布尔标志用来判断游戏结束与否
    
    """
    
    # 图像预处理
    """
    将彩色图像转换为灰阶图
    调整图像的大小为80 X 80像素
    提供4张图像给神经网络进行训练
    """
    x_t = skimage.color.rgb2gray(x_t)
    x_t = skimage.transform.resize(x_t,(80,80))
    x_t = skimage.exposure.rescale_intensity(x_t,out_range=(0,255))

    
    
    x_t = x_t / 255.0

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)

    #调整成Keras能吃的数据格式
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*80*80*4

    

    if args['mode'] == 'Run':
        OBSERVE = 999999999    #只观测，不训练
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #进入训练模式
        OBSERVE = OBSERVATION
        epsilon = INITIAL_EPSILON

    t = 0
    while (True):
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0
        a_t = np.zeros([ACTIONS])
        # 采用epsilon greedy当成动作
        if t % FRAME_PER_ACTION == 0:
            if random.random() <= epsilon:
                # 随机动作
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else:
                q = model.predict(s_t)       #输入四张图以取得预测结果
                # 采取最大Q值动作
                max_Q = np.argmax(q)
                action_index = max_Q
                a_t[max_Q] = 1

        # 渐渐降低epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        # 执行动作并且观测出状态与奖励
        x_t1_colored, r_t, terminal = game_state.frame_step(a_t)
        """
        r_t 代表 reward
        r_t 分为三种：
        0.1 : 代表bird活著
        +1  : 代表bird通过了水管
        -1  : 代表bird死亡
        """

        # 图像预处理
        """
        将彩色图像转换为灰阶图
        调整图像的大小为80 X 80像素
        提供4张图像给神经网络进行训练
        """
        x_t1 = skimage.color.rgb2gray(x_t1_colored)
        x_t1 = skimage.transform.resize(x_t1,(80,80))
        x_t1 = skimage.exposure.rescale_intensity(x_t1, out_range=(0, 255))


        x_t1 = x_t1 / 255.0


        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x80x80x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3)

        # 所有的episode(s,a,r,s′)都会存储在重放表格d中
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #结束观测后只单纯训练

        if t > OBSERVE:
            # 采样mini-batch做资料训练
            minibatch = random.sample(D, BATCH)

            # 经验回放 (Exprience Replay) 
            state_t, action_t, reward_t, state_t1, terminal = zip(*minibatch) # (s,a,r,s′)
            state_t = np.concatenate(state_t)
            state_t1 = np.concatenate(state_t1)
            targets = model.predict(state_t)
            Q_sa = model.predict(state_t1)
            targets[range(BATCH), action_t] = reward_t + GAMMA*np.max(Q_sa, axis=1)*np.invert(terminal)

            loss += model.train_on_batch(state_t, targets)

        s_t = s_t1
        t = t + 1

        #每一千次存储模型
        if t % 1000 == 0:
            print("Now we save model")
            model.save_weights("model.h5", overwrite=True)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)

        # 印出相关资讯
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %% [markdown]
# ## 建立 Convolution Neural Network

# %%
def buildmodel():
    model = Sequential()
    #80*80*4 => 20*20*32 
    model.add(Convolution2D(32, 8, 8, subsample=(4, 4), border_mode='same',input_shape=(img_rows,img_cols,img_channels)))  
    model.add(Activation('relu'))
    #20*20*32 => 10*10*64
    model.add(Convolution2D(64, 4, 4, subsample=(2, 2), border_mode='same'))
    model.add(Activation('relu'))
    #10*10*64 => 10*10*64
    model.add(Convolution2D(64, 3, 3, subsample=(1, 1), border_mode='same'))
    model.add(Activation('relu'))
    # 10*10*64 => 6400
    model.add(Flatten())
    # 6400 => 512
    model.add(Dense(512))
    model.add(Activation('relu'))
    # 512 => 2
    model.add(Dense(2))
    
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    model.summary()
    return model

# %%
buildmodel()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# activation_5 (Activation)    (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 64)        32832
# _________________________________________________________________
# activation_6 (Activation)    (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# activation_7 (Activation)    (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               3277312
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,356,322
# Trainable params: 3,356,322
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\davidchiu\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 8), input_shape=(80, 80, 4..., strides=(4, 4), padding="same")`
#   after removing the cwd from sys.path.
# C:\Users\davidchiu\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), strides=(2, 2), padding="same")`
#   import sys
# C:\Users\davidchiu\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), strides=(1, 1), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.

# %%
def playGame(args):
    model = buildmodel()
    trainNetwork(model,args)

# %%
playGame({'mode':'Train'})
# Out:
# C:\Users\davidchiu\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 8), input_shape=(80, 80, 4..., strides=(4, 4), padding="same")`
#   after removing the cwd from sys.path.
# C:\Users\davidchiu\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), strides=(2, 2), padding="same")`
#   import sys
# C:\Users\davidchiu\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), strides=(1, 1), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\davidchiu\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 20, 20, 32)        8224
# _________________________________________________________________
# activation_13 (Activation)   (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 10, 10, 64)        32832
# _________________________________________________________________
# activation_14 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 10, 10, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               3277312
# _________________________________________________________________
# activation_16 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,356,322
# Trainable params: 3,356,322
# Non-trainable params: 0
# _________________________________________________________________
# ----------Random Action----------
# TIMESTEP 1 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 2 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 3 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 4 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 5 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 6 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 7 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 8 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 9 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 10 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 11 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 12 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 13 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 14 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 15 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 16 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 17 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 18 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 19 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 20 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 21 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 22 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 23 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 24 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 25 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 26 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 27 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 28 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 29 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 30 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 31 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 32 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 33 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 34 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 35 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 36 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 37 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 38 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 39 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 40 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 41 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 42 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 43 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 44 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 45 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 46 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 47 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 48 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 49 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 50 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 51 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 52 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 53 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 54 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 55 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 56 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 57 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 58 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 59 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 60 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 61 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 62 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 63 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 64 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 65 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 66 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 67 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 68 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 69 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 70 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 71 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 72 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 73 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 74 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 75 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 76 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 77 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 78 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 79 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 80 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 81 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 82 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 83 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 84 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 85 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 86 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 87 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 88 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 89 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 90 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 91 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 92 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 93 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 94 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 95 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 96 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 97 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 98 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 99 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 100 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 101 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 102 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 103 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 104 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 105 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 106 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 107 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 108 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 109 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 110 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 111 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 112 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 113 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 114 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 115 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 116 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 117 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 118 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 119 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 120 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 121 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 122 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 123 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 124 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 125 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 126 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 127 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 128 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 129 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 130 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 131 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 132 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 133 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 134 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 135 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 136 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 137 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 138 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 139 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 140 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 141 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 142 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 143 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 144 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 145 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 146 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 147 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 148 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 149 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 150 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 151 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 152 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 153 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 154 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 155 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 156 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 157 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 158 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 159 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 160 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 161 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 162 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 163 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 164 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 165 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 166 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 167 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 168 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 169 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 170 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 171 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 172 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 173 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 174 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 175 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 176 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 177 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 178 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 179 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 180 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 181 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 182 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 183 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 184 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 185 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 186 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 187 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 188 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 189 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 190 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 191 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 192 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 193 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 194 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 195 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 196 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 197 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 198 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 199 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 200 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 201 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 202 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 203 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 204 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 205 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 206 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 207 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 208 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 209 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 210 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 211 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 212 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 213 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 214 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 215 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 216 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 217 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 218 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 219 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 220 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 221 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 222 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 223 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 224 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 225 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 226 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 227 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 228 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 229 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 230 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 231 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 232 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 233 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 234 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 235 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 236 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 237 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 238 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 239 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 240 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 241 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 242 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 243 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 244 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 245 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 246 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 247 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 248 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 249 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 250 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 251 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 252 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 253 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 254 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 255 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 256 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 257 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 258 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 259 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 260 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 261 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 262 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 263 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 264 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 265 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 266 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 267 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 268 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 269 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 270 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 271 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 272 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 273 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 274 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 275 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 276 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 277 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 278 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 279 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 280 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 281 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 282 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 283 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 284 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 285 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 286 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 287 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 288 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 289 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 290 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 291 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 292 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 293 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 294 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 295 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 296 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 297 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 298 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 299 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 300 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 301 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 302 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 303 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 304 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 305 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 306 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 307 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 308 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 309 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 310 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 311 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 312 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 313 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 314 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 315 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 316 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 317 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 318 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 319 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 320 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 321 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 322 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 323 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 324 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 325 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 326 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 327 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 328 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 329 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 330 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 331 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 332 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 333 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 334 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 335 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 336 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 337 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 338 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 339 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 340 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 341 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 342 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 343 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 344 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 345 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 346 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 347 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 348 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 349 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 350 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 351 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 352 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 353 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 354 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 355 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 356 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 357 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 358 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 359 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 360 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 361 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 362 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 363 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 364 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 365 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 366 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 367 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 368 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 369 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 370 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 371 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 372 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 373 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 374 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 375 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 376 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 377 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 378 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 379 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 380 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 381 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 382 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 383 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 384 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 385 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 386 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 387 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 388 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 389 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 390 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 391 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 392 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 393 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 394 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 395 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 396 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 397 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 398 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 399 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 400 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 401 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 402 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 403 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 404 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 405 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 406 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 407 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 408 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 409 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 410 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 411 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 412 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 413 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 414 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 415 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 416 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 417 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 418 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 419 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 420 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 421 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 422 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 423 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 424 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 425 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 426 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 427 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 428 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 429 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 430 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 431 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 432 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 433 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 434 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 435 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 436 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 437 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 438 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 439 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 440 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 441 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 442 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 443 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 444 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 445 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 446 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 447 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 448 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 449 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 450 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 451 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 452 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 453 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 454 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 455 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 456 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 457 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 458 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 459 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 460 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 461 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 462 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 463 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 464 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 465 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 466 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 467 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 468 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 469 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 470 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 471 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 472 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 473 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 474 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 475 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 476 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 477 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 478 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 479 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 480 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 481 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 482 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 483 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 484 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 485 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 486 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 487 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 488 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 489 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 490 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 491 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 492 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 493 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 494 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 495 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 496 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 497 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 498 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ...
# TIMESTEP 3358 / STATE explore / EPSILON 0.09999477190000101 / ACTION 1 / REWARD 0.1 / Q_MAX  213.06107 / Loss  20.222999572753906
# TIMESTEP 3359 / STATE explore / EPSILON 0.09999473860000102 / ACTION 1 / REWARD 0.1 / Q_MAX  203.69344 / Loss  185.7047882080078
# ----------Random Action----------
# TIMESTEP 3360 / STATE explore / EPSILON 0.09999470530000103 / ACTION 0 / REWARD 1 / Q_MAX  192.38863 / Loss  150.00584411621094
# TIMESTEP 3361 / STATE explore / EPSILON 0.09999467200000103 / ACTION 1 / REWARD 0.1 / Q_MAX  181.83781 / Loss  21.280839920043945
# TIMESTEP 3362 / STATE explore / EPSILON 0.09999463870000104 / ACTION 1 / REWARD 0.1 / Q_MAX  174.34592 / Loss  4.924396991729736
# ----------Random Action----------
# TIMESTEP 3363 / STATE explore / EPSILON 0.09999460540000105 / ACTION 0 / REWARD 0.1 / Q_MAX  163.9988 / Loss  67.27050018310547
# TIMESTEP 3364 / STATE explore / EPSILON 0.09999457210000105 / ACTION 1 / REWARD -1 / Q_MAX  191.55916 / Loss  28.143150329589844
# TIMESTEP 3365 / STATE explore / EPSILON 0.09999453880000106 / ACTION 1 / REWARD 0.1 / Q_MAX  145.35342 / Loss  14.032665252685547
# ----------Random Action----------
# TIMESTEP 3366 / STATE explore / EPSILON 0.09999450550000107 / ACTION 1 / REWARD 0.1 / Q_MAX  171.32095 / Loss  27.882478713989258
# TIMESTEP 3367 / STATE explore / EPSILON 0.09999447220000107 / ACTION 1 / REWARD 0.1 / Q_MAX  128.67331 / Loss  24.27099609375
# TIMESTEP 3368 / STATE explore / EPSILON 0.09999443890000108 / ACTION 1 / REWARD 0.1 / Q_MAX  136.35764 / Loss  17.21124267578125
# TIMESTEP 3369 / STATE explore / EPSILON 0.09999440560000109 / ACTION 1 / REWARD 0.1 / Q_MAX  136.10355 / Loss  29.139896392822266
# TIMESTEP 3370 / STATE explore / EPSILON 0.09999437230000109 / ACTION 1 / REWARD 0.1 / Q_MAX  138.46506 / Loss  34.633914947509766
# TIMESTEP 3371 / STATE explore / EPSILON 0.0999943390000011 / ACTION 1 / REWARD 0.1 / Q_MAX  143.45723 / Loss  28.71162223815918
# TIMESTEP 3372 / STATE explore / EPSILON 0.0999943057000011 / ACTION 1 / REWARD 0.1 / Q_MAX  149.24437 / Loss  6.507811546325684
# TIMESTEP 3373 / STATE explore / EPSILON 0.09999427240000111 / ACTION 1 / REWARD 0.1 / Q_MAX  154.9351 / Loss  17.884977340698242
# TIMESTEP 3374 / STATE explore / EPSILON 0.09999423910000112 / ACTION 1 / REWARD 0.1 / Q_MAX  161.506 / Loss  13.269257545471191
# TIMESTEP 3375 / STATE explore / EPSILON 0.09999420580000112 / ACTION 1 / REWARD 0.1 / Q_MAX  166.70212 / Loss  50.762718200683594
# TIMESTEP 3376 / STATE explore / EPSILON 0.09999417250000113 / ACTION 1 / REWARD 0.1 / Q_MAX  170.42871 / Loss  48.8028564453125
# TIMESTEP 3377 / STATE explore / EPSILON 0.09999413920000114 / ACTION 1 / REWARD 0.1 / Q_MAX  172.63988 / Loss  29.027820587158203
# TIMESTEP 3378 / STATE explore / EPSILON 0.09999410590000114 / ACTION 1 / REWARD 0.1 / Q_MAX  170.51697 / Loss  15.374691009521484
# ----------Random Action----------
# TIMESTEP 3379 / STATE explore / EPSILON 0.09999407260000115 / ACTION 0 / REWARD 0.1 / Q_MAX  175.42108 / Loss  38.114070892333984
# TIMESTEP 3380 / STATE explore / EPSILON 0.09999403930000116 / ACTION 1 / REWARD 0.1 / Q_MAX  176.50858 / Loss  22.129121780395508
# TIMESTEP 3381 / STATE explore / EPSILON 0.09999400600000116 / ACTION 1 / REWARD 0.1 / Q_MAX  182.06088 / Loss  26.203815460205078
# TIMESTEP 3382 / STATE explore / EPSILON 0.09999397270000117 / ACTION 1 / REWARD 0.1 / Q_MAX  189.57764 / Loss  2.3682150840759277
# TIMESTEP 3383 / STATE explore / EPSILON 0.09999393940000117 / ACTION 1 / REWARD 0.1 / Q_MAX  194.4551 / Loss  3.746716022491455
# TIMESTEP 3384 / STATE explore / EPSILON 0.09999390610000118 / ACTION 1 / REWARD 0.1 / Q_MAX  202.35922 / Loss  12.022170066833496
# TIMESTEP 3385 / STATE explore / EPSILON 0.09999387280000119 / ACTION 0 / REWARD 0.1 / Q_MAX  204.82507 / Loss  5.896351337432861
# TIMESTEP 3386 / STATE explore / EPSILON 0.0999938395000012 / ACTION 0 / REWARD 0.1 / Q_MAX  210.12917 / Loss  92.43301391601562
# TIMESTEP 3387 / STATE explore / EPSILON 0.0999938062000012 / ACTION 0 / REWARD 0.1 / Q_MAX  214.97562 / Loss  8.560744285583496
# TIMESTEP 3388 / STATE explore / EPSILON 0.09999377290000121 / ACTION 0 / REWARD 0.1 / Q_MAX  226.53609 / Loss  129.01951599121094
# TIMESTEP 3389 / STATE explore / EPSILON 0.09999373960000121 / ACTION 0 / REWARD 0.1 / Q_MAX  284.8612 / Loss  78.02516174316406
# TIMESTEP 3390 / STATE explore / EPSILON 0.09999370630000122 / ACTION 0 / REWARD 0.1 / Q_MAX  226.38585 / Loss  33.008575439453125
# TIMESTEP 3391 / STATE explore / EPSILON 0.09999367300000123 / ACTION 0 / REWARD 0.1 / Q_MAX  233.07071 / Loss  57.365455627441406
# ----------Random Action----------
# TIMESTEP 3392 / STATE explore / EPSILON 0.09999363970000123 / ACTION 1 / REWARD 0.1 / Q_MAX  244.01619 / Loss  164.31008911132812
# TIMESTEP 3393 / STATE explore / EPSILON 0.09999360640000124 / ACTION 0 / REWARD 0.1 / Q_MAX  254.08385 / Loss  12.879456520080566
# TIMESTEP 3394 / STATE explore / EPSILON 0.09999357310000125 / ACTION 0 / REWARD 0.1 / Q_MAX  263.16415 / Loss  5.5988335609436035
# ----------Random Action----------
# TIMESTEP 3395 / STATE explore / EPSILON 0.09999353980000125 / ACTION 1 / REWARD 0.1 / Q_MAX  276.12033 / Loss  25.003334045410156
# TIMESTEP 3396 / STATE explore / EPSILON 0.09999350650000126 / ACTION 1 / REWARD 0.1 / Q_MAX  278.6564 / Loss  133.45684814453125
# TIMESTEP 3397 / STATE explore / EPSILON 0.09999347320000126 / ACTION 0 / REWARD 0.1 / Q_MAX  268.19333 / Loss  107.33759307861328
# TIMESTEP 3398 / STATE explore / EPSILON 0.09999343990000127 / ACTION 0 / REWARD 0.1 / Q_MAX  263.63614 / Loss  39.112754821777344
# TIMESTEP 3399 / STATE explore / EPSILON 0.09999340660000128 / ACTION 0 / REWARD 0.1 / Q_MAX  264.63754 / Loss  78.30696105957031
# TIMESTEP 3400 / STATE explore / EPSILON 0.09999337330000128 / ACTION 0 / REWARD 0.1 / Q_MAX  263.82776 / Loss  66.89446258544922
# TIMESTEP 3401 / STATE explore / EPSILON 0.09999334000000129 / ACTION 0 / REWARD 0.1 / Q_MAX  324.6562 / Loss  32.45155334472656
# TIMESTEP 3402 / STATE explore / EPSILON 0.0999933067000013 / ACTION 0 / REWARD 0.1 / Q_MAX  274.0404 / Loss  31.83562469482422
# TIMESTEP 3403 / STATE explore / EPSILON 0.0999932734000013 / ACTION 0 / REWARD 0.1 / Q_MAX  342.6774 / Loss  120.09074401855469
# TIMESTEP 3404 / STATE explore / EPSILON 0.09999324010000131 / ACTION 0 / REWARD 0.1 / Q_MAX  292.65018 / Loss  30.24141502380371
# TIMESTEP 3405 / STATE explore / EPSILON 0.09999320680000132 / ACTION 1 / REWARD 0.1 / Q_MAX  300.04782 / Loss  306.4619140625
# TIMESTEP 3406 / STATE explore / EPSILON 0.09999317350000132 / ACTION 1 / REWARD 0.1 / Q_MAX  301.3277 / Loss  226.13290405273438
# TIMESTEP 3407 / STATE explore / EPSILON 0.09999314020000133 / ACTION 1 / REWARD 0.1 / Q_MAX  289.81372 / Loss  284.3929138183594
# TIMESTEP 3408 / STATE explore / EPSILON 0.09999310690000134 / ACTION 1 / REWARD 0.1 / Q_MAX  274.91873 / Loss  7.530606269836426
# ----------Random Action----------
# TIMESTEP 3409 / STATE explore / EPSILON 0.09999307360000134 / ACTION 1 / REWARD 0.1 / Q_MAX  265.17096 / Loss  26.387300491333008
# TIMESTEP 3410 / STATE explore / EPSILON 0.09999304030000135 / ACTION 0 / REWARD 0.1 / Q_MAX  255.65427 / Loss  103.69316101074219
# TIMESTEP 3411 / STATE explore / EPSILON 0.09999300700000135 / ACTION 0 / REWARD 0.1 / Q_MAX  267.30798 / Loss  62.346073150634766
# TIMESTEP 3412 / STATE explore / EPSILON 0.09999297370000136 / ACTION 0 / REWARD 0.1 / Q_MAX  268.96478 / Loss  58.46839141845703
# ----------Random Action----------
# TIMESTEP 3413 / STATE explore / EPSILON 0.09999294040000137 / ACTION 0 / REWARD 0.1 / Q_MAX  274.4199 / Loss  39.05971145629883
# ----------Random Action----------
# TIMESTEP 3414 / STATE explore / EPSILON 0.09999290710000137 / ACTION 1 / REWARD -1 / Q_MAX  287.56094 / Loss  10.599863052368164
# ----------Random Action----------
# TIMESTEP 3415 / STATE explore / EPSILON 0.09999287380000138 / ACTION 0 / REWARD 0.1 / Q_MAX  301.435 / Loss  134.7672882080078
# TIMESTEP 3416 / STATE explore / EPSILON 0.09999284050000139 / ACTION 1 / REWARD 0.1 / Q_MAX  313.27344 / Loss  100.36138916015625
# TIMESTEP 3417 / STATE explore / EPSILON 0.0999928072000014 / ACTION 1 / REWARD 0.1 / Q_MAX  321.50345 / Loss  100.16789245605469
# TIMESTEP 3418 / STATE explore / EPSILON 0.0999927739000014 / ACTION 1 / REWARD 0.1 / Q_MAX  321.04105 / Loss  86.81327056884766
# TIMESTEP 3419 / STATE explore / EPSILON 0.0999927406000014 / ACTION 1 / REWARD 0.1 / Q_MAX  322.15237 / Loss  179.10903930664062
# TIMESTEP 3420 / STATE explore / EPSILON 0.09999270730000141 / ACTION 1 / REWARD 0.1 / Q_MAX  317.47455 / Loss  346.747802734375
# TIMESTEP 3421 / STATE explore / EPSILON 0.09999267400000142 / ACTION 1 / REWARD 0.1 / Q_MAX  306.60983 / Loss  97.79277038574219
# TIMESTEP 3422 / STATE explore / EPSILON 0.09999264070000143 / ACTION 1 / REWARD 0.1 / Q_MAX  300.06955 / Loss  31.592300415039062
# TIMESTEP 3423 / STATE explore / EPSILON 0.09999260740000143 / ACTION 1 / REWARD 0.1 / Q_MAX  296.96738 / Loss  80.20648956298828
# ----------Random Action----------
# TIMESTEP 3424 / STATE explore / EPSILON 0.09999257410000144 / ACTION 0 / REWARD 0.1 / Q_MAX  295.69904 / Loss  28.037681579589844
# TIMESTEP 3425 / STATE explore / EPSILON 0.09999254080000144 / ACTION 1 / REWARD 0.1 / Q_MAX  309.71747 / Loss  22.008934020996094
# TIMESTEP 3426 / STATE explore / EPSILON 0.09999250750000145 / ACTION 1 / REWARD 0.1 / Q_MAX  301.77097 / Loss  62.65355682373047
# TIMESTEP 3427 / STATE explore / EPSILON 0.09999247420000146 / ACTION 1 / REWARD 0.1 / Q_MAX  313.25662 / Loss  46.39227294921875
# TIMESTEP 3428 / STATE explore / EPSILON 0.09999244090000146 / ACTION 1 / REWARD 0.1 / Q_MAX  326.517 / Loss  69.14839172363281
# TIMESTEP 3429 / STATE explore / EPSILON 0.09999240760000147 / ACTION 1 / REWARD 0.1 / Q_MAX  340.4946 / Loss  21.37811279296875
# ----------Random Action----------
# TIMESTEP 3430 / STATE explore / EPSILON 0.09999237430000148 / ACTION 1 / REWARD 0.1 / Q_MAX  353.8174 / Loss  384.45147705078125
# TIMESTEP 3431 / STATE explore / EPSILON 0.09999234100000148 / ACTION 1 / REWARD 0.1 / Q_MAX  343.22284 / Loss  38.149932861328125
# ----------Random Action----------
# TIMESTEP 3432 / STATE explore / EPSILON 0.09999230770000149 / ACTION 0 / REWARD 0.1 / Q_MAX  361.47278 / Loss  52.6834716796875
# TIMESTEP 3433 / STATE explore / EPSILON 0.0999922744000015 / ACTION 1 / REWARD 0.1 / Q_MAX  353.2324 / Loss  43.5460205078125
# TIMESTEP 3434 / STATE explore / EPSILON 0.0999922411000015 / ACTION 1 / REWARD 0.1 / Q_MAX  343.2576 / Loss  27.693592071533203
# TIMESTEP 3435 / STATE explore / EPSILON 0.09999220780000151 / ACTION 0 / REWARD 0.1 / Q_MAX  324.4494 / Loss  115.51300811767578
# TIMESTEP 3436 / STATE explore / EPSILON 0.09999217450000152 / ACTION 0 / REWARD 0.1 / Q_MAX  372.64404 / Loss  33.923221588134766
# TIMESTEP 3437 / STATE explore / EPSILON 0.09999214120000152 / ACTION 0 / REWARD 0.1 / Q_MAX  291.2674 / Loss  10.624540328979492
# TIMESTEP 3438 / STATE explore / EPSILON 0.09999210790000153 / ACTION 0 / REWARD 0.1 / Q_MAX  266.47983 / Loss  35.325645446777344
# TIMESTEP 3439 / STATE explore / EPSILON 0.09999207460000153 / ACTION 0 / REWARD 0.1 / Q_MAX  250.90831 / Loss  12.472675323486328
# TIMESTEP 3440 / STATE explore / EPSILON 0.09999204130000154 / ACTION 0 / REWARD 0.1 / Q_MAX  251.39195 / Loss  32.85404968261719
# TIMESTEP 3441 / STATE explore / EPSILON 0.09999200800000155 / ACTION 0 / REWARD 0.1 / Q_MAX  243.58482 / Loss  18.296018600463867
# TIMESTEP 3442 / STATE explore / EPSILON 0.09999197470000155 / ACTION 0 / REWARD 0.1 / Q_MAX  237.49292 / Loss  13.451446533203125
# TIMESTEP 3443 / STATE explore / EPSILON 0.09999194140000156 / ACTION 0 / REWARD 0.1 / Q_MAX  236.09064 / Loss  7.358635902404785
# TIMESTEP 3444 / STATE explore / EPSILON 0.09999190810000157 / ACTION 0 / REWARD 0.1 / Q_MAX  230.32375 / Loss  12.367966651916504
# TIMESTEP 3445 / STATE explore / EPSILON 0.09999187480000157 / ACTION 0 / REWARD 0.1 / Q_MAX  231.21245 / Loss  6.698103904724121
# TIMESTEP 3446 / STATE explore / EPSILON 0.09999184150000158 / ACTION 0 / REWARD 0.1 / Q_MAX  228.82191 / Loss  19.116863250732422
# TIMESTEP 3447 / STATE explore / EPSILON 0.09999180820000159 / ACTION 0 / REWARD 0.1 / Q_MAX  223.07774 / Loss  28.68067169189453
# TIMESTEP 3448 / STATE explore / EPSILON 0.09999177490000159 / ACTION 1 / REWARD 0.1 / Q_MAX  222.62315 / Loss  14.715510368347168
# TIMESTEP 3449 / STATE explore / EPSILON 0.0999917416000016 / ACTION 1 / REWARD 0.1 / Q_MAX  273.66736 / Loss  16.425439834594727
# TIMESTEP 3450 / STATE explore / EPSILON 0.0999917083000016 / ACTION 1 / REWARD 0.1 / Q_MAX  219.28503 / Loss  10.66927433013916
# TIMESTEP 3451 / STATE explore / EPSILON 0.09999167500000161 / ACTION 1 / REWARD 0.1 / Q_MAX  207.37071 / Loss  18.288705825805664
# ----------Random Action----------
# TIMESTEP 3452 / STATE explore / EPSILON 0.09999164170000162 / ACTION 0 / REWARD 0.1 / Q_MAX  224.72104 / Loss  20.05254364013672
# TIMESTEP 3453 / STATE explore / EPSILON 0.09999160840000162 / ACTION 1 / REWARD 0.1 / Q_MAX  207.56192 / Loss  14.938016891479492
# ----------Random Action----------
# TIMESTEP 3454 / STATE explore / EPSILON 0.09999157510000163 / ACTION 0 / REWARD 0.1 / Q_MAX  210.9638 / Loss  32.058319091796875
# ----------Random Action----------
# TIMESTEP 3455 / STATE explore / EPSILON 0.09999154180000164 / ACTION 1 / REWARD 0.1 / Q_MAX  210.44374 / Loss  21.637889862060547
# TIMESTEP 3456 / STATE explore / EPSILON 0.09999150850000164 / ACTION 1 / REWARD 0.1 / Q_MAX  197.9701 / Loss  12.506195068359375
# TIMESTEP 3457 / STATE explore / EPSILON 0.09999147520000165 / ACTION 1 / REWARD 0.1 / Q_MAX  203.45937 / Loss  11.359155654907227
# TIMESTEP 3458 / STATE explore / EPSILON 0.09999144190000166 / ACTION 1 / REWARD 0.1 / Q_MAX  217.36598 / Loss  19.404943466186523
# TIMESTEP 3459 / STATE explore / EPSILON 0.09999140860000166 / ACTION 1 / REWARD 0.1 / Q_MAX  235.76842 / Loss  10.587950706481934
# TIMESTEP 3460 / STATE explore / EPSILON 0.09999137530000167 / ACTION 0 / REWARD 0.1 / Q_MAX  221.12825 / Loss  8.518896102905273
# TIMESTEP 3461 / STATE explore / EPSILON 0.09999134200000168 / ACTION 0 / REWARD 0.1 / Q_MAX  225.41316 / Loss  10.019194602966309
# TIMESTEP 3462 / STATE explore / EPSILON 0.09999130870000168 / ACTION 0 / REWARD 0.1 / Q_MAX  229.03644 / Loss  25.671037673950195
# TIMESTEP 3463 / STATE explore / EPSILON 0.09999127540000169 / ACTION 0 / REWARD 0.1 / Q_MAX  228.05048 / Loss  12.558538436889648
# TIMESTEP 3464 / STATE explore / EPSILON 0.0999912421000017 / ACTION 0 / REWARD -1 / Q_MAX  229.26144 / Loss  14.781852722167969
# TIMESTEP 3465 / STATE explore / EPSILON 0.0999912088000017 / ACTION 1 / REWARD 0.1 / Q_MAX  225.89265 / Loss  30.59200668334961
# TIMESTEP 3466 / STATE explore / EPSILON 0.09999117550000171 / ACTION 1 / REWARD 0.1 / Q_MAX  279.2526 / Loss  89.4715805053711
# TIMESTEP 3467 / STATE explore / EPSILON 0.09999114220000171 / ACTION 1 / REWARD 0.1 / Q_MAX  221.68939 / Loss  6.853403091430664
# TIMESTEP 3468 / STATE explore / EPSILON 0.09999110890000172 / ACTION 1 / REWARD 0.1 / Q_MAX  218.91394 / Loss  38.75367736816406
# ----------Random Action----------
# TIMESTEP 3469 / STATE explore / EPSILON 0.09999107560000173 / ACTION 1 / REWARD 0.1 / Q_MAX  270.39474 / Loss  35.015472412109375
# TIMESTEP 3470 / STATE explore / EPSILON 0.09999104230000173 / ACTION 1 / REWARD 0.1 / Q_MAX  209.09346 / Loss  22.81818962097168
# TIMESTEP 3471 / STATE explore / EPSILON 0.09999100900000174 / ACTION 1 / REWARD 0.1 / Q_MAX  210.83263 / Loss  9.135249137878418
# TIMESTEP 3472 / STATE explore / EPSILON 0.09999097570000175 / ACTION 1 / REWARD 0.1 / Q_MAX  207.16644 / Loss  5.115880966186523
# TIMESTEP 3473 / STATE explore / EPSILON 0.09999094240000175 / ACTION 1 / REWARD 0.1 / Q_MAX  202.26381 / Loss  4.7791242599487305
# ----------Random Action----------
# TIMESTEP 3474 / STATE explore / EPSILON 0.09999090910000176 / ACTION 0 / REWARD 0.1 / Q_MAX  201.50746 / Loss  7.303746223449707
# TIMESTEP 3475 / STATE explore / EPSILON 0.09999087580000177 / ACTION 1 / REWARD 0.1 / Q_MAX  195.78043 / Loss  14.121448516845703
# TIMESTEP 3476 / STATE explore / EPSILON 0.09999084250000177 / ACTION 1 / REWARD 0.1 / Q_MAX  191.70331 / Loss  64.68329620361328
